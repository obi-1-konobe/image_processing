# %%
# %matplotlib inline

# %%
from skimage.io import imread, imshow, imsave

# %%
img = imread('images/tiger.jpg')

# %%
imshow(img)

# %%
img.shape
# Out:
# (1600, 2560, 3)

# %%
img[383, 384]
# Out:
# array([255, 255,   0], dtype=uint8)

# %%
img[383, 384, 1]
# Out:
# 69

# %%
img[383, 384] = [255, 255, 0]

# %%
imsave('tiger_yellow.png', img)

# %%
nose = img[800:1000, 800:1000]

# %%
imshow(nose)

# %%
img[800:1000, 800:1000] = [255, 0, 255]

# %%
imshow(img)

# %%
img_yellow = imread('images/tiger_yellow.png')

# %%
imshow(img_yellow[300:400, 300:400])
# Out:
# /home/aldik/.local/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
border = imread('images/tiger-border.png')

# %%
border[38, 200]
# Out:
# array([ 81, 243, 165], dtype=uint8)

# %%
imshow(border)

# %%
border.shape[1] // 2
# Out:
# 413

# %%
border[38, 413][0]
# Out:
# 81

# %%
border.shape
# Out:
# (646, 826, 3)

# %%
if border[0,0].any() == border[1, 0].all():
    print(123)
# Out:
# 123

# %%
import numpy as np
np.array_equal(border[0,0], border[1,0])
# Out:
# True
